# %% [markdown]
# # imports
# import numpy as np
# import pandas as pd
# from sklearn.datasets import make_classification
# from sklearn.metrics import precision_score
# from sklearn.metrics import accuracy_score
# from random import random
# from random import seed
# from math import exp
# from sklearn.metrics import recall_score
# from sklearn.metrics import confusion_matrix

# %%
# No. of rows(rows)
no_of_samples = 200

# No. of features {F1,F2,F3,F4}=4
no_of_features = 4

# No. of redundent features (Extra Feature)
no_of_extra = 1

#types of classes
types_of_classes = 2

# %%
X, y = make_classification(n_samples=no_of_samples, n_features=no_of_features,
                                            n_redundant=no_of_extra, n_classes=types_of_classes)
df = pd.DataFrame(X, columns=['F1', 'F2', 'F3', 'F4'])

# %%
#reading the csv file by using pandas 

df=pd.read_csv('assignment.csv',index_col=0)
df.head()
# Out:
#              F1        F2        F3        F4  L1
# S No.
# 0      0.989952 -0.216663 -0.840217  0.247416   0
# 1     -0.053900 -1.854247  1.481230  0.798278   1
# 2     -1.020268  1.747037 -2.276463 -0.618126   0
# 3     -0.514083 -1.461922 -1.395697  1.019334   0
# 4     -0.771490  0.828319  1.436928 -0.675839   1

# %%
#creating the network for weights

def create_W(n_inp, n_hid, n_out):
    net=list()
    H_layer = [{'W':[random() for i in range(n_inp + 1)]} for i in range(n_hid)]
    net.append(H_layer)
    O_layer = [{'W':[random() for i in range(n_hid + 1)]} for i in range(n_out)]
    net.append(O_layer)
    return net

# %%
#activation function for MLP

def activate(W, inp):
    activation=W[-1]
    for i in range(len(W)-1):
        activation+=W[i]*inp[i]
    return activation

def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
#forward propogation to pass it on next layer using activation function

def propagation_next_layer(net,raw):
    inp=raw
    for layer in net:
        new_inp=[]
        for neuron in layer:
            activation=activate(neuron['W'], inp)
            neuron['output']=transfer(activation)
            new_inp.append(neuron['output'])
        inp=new_inp
    return inp

def transfer_derivative(out):
    return out * (1.0 - out)

# %%
#backward propogation to learn for fine tuning the weights

def backward_learn(net, expected):
    for i in reversed(range(len(net))):
        layer = net[i]
        errors = list()
        if i != len(net)-1:
            for ind in range(len(layer)):
                err = 0.0
                for neuron in net[i + 1]:
                    err += (neuron['W'][ind] * neuron['delta'])
                errors.append(err)
        else:
            for index in range(len(layer)):
                neuron = layer[index]
                errors.append(expected[index] - neuron['output'])
        for index in range(len(layer)):
            neuron = layer[index]
            neuron['delta'] = errors[index] * transfer_derivative(neuron['output'])

# %%
#update weights W on training the algo

def update_W_train(net, row, l_rate):
    for i in range(len(net)):
        inp=row[:-1]
        if i!=0:
            inp=[neuron['output'] for neuron in net[i-1]]
        for neuron in net[i]:
            for j in range(len(inp)):
                neuron['W'][j]+=l_rate*neuron['delta']*inp[j]
            neuron['W'][-1]+=l_rate*neuron['delta']

# %%
#training the network

def train_MLP(net, train, l_rate, n_epoch, n_out):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            out = propagation_next_layer(net, row)
            expected = [0 for i in range(n_out)]
            expected[int(row[-1])] = 1
            sum_error += sum([(expected[i]-out[i])**2 for i in range(len(expected))])
            backward_learn(net, expected)
            update_W_train(net, row, l_rate)
        print('=>epoch=%d, =>lrate=%.3f, =>error=%.3f' % (epoch, l_rate, sum_error))

# %%
#predicting function

def prediction_def(net, row):
    out = propagation_next_layer(net, row)
    return out.index(max(out))

# %%
dataset=np.array(df[:])
dataset
# Out:
# array([[ 9.89951561e-01, -2.16663363e-01, -8.40216728e-01,
#          2.47416467e-01,  0.00000000e+00],
#        [-5.38998510e-02, -1.85424690e+00,  1.48123049e+00,
#          7.98277529e-01,  1.00000000e+00],
#        [-1.02026781e+00,  1.74703732e+00, -2.27646339e+00,
#         -6.18125619e-01,  0.00000000e+00],
#        [-5.14082520e-01, -1.46192216e+00, -1.39569663e+00,
#          1.01933443e+00,  0.00000000e+00],
#        [-7.71490282e-01,  8.28319117e-01,  1.43692804e+00,
#         -6.75838889e-01,  1.00000000e+00],
#        [ 8.48094534e-01, -1.78161924e+00, -2.62461131e+00,
#          1.38275642e+00,  0.00000000e+00],
#        [-1.93022008e-01, -9.74753567e-01,  5.83147698e-01,
#          4.49385607e-01,  1.00000000e+00],
#        [-6.03853857e-01, -1.70014910e-01, -2.61601874e+00,
#          4.91796189e-01,  0.00000000e+00],
#        [ 7.16873650e-01, -8.74769329e-01, -1.06727973e+00,
#          6.45250699e-01,  0.00000000e+00],
#        [-9.99038769e-01, -1.11815481e+00, -1.08217200e+00,
#          7.81872044e-01,  0.00000000e+00],
#        [ 5.31552796e-01, -1.19916884e+00, -6.39944600e-03,
#          6.62950056e-01,  0.00000000e+00],
#        [-8.72943113e-01,  4.75148502e-01,  3.23917788e-01,
#         -3.11569648e-01,  1.00000000e+00],
#        [-1.09673338e+00, -6.56354887e-01,  1.11223671e+00,
#          1.93136297e-01,  1.00000000e+00],
#        [ 1.62667995e-01,  1.82831657e+00,  1.75913172e+00,
#         -1.27687990e+00,  1.00000000e+00],
#        [-9.48802977e-01,  9.87363995e-01,  1.72748750e+00,
#         -8.07835613e-01,  1.00000000e+00],
#        [ 7.93917025e-01,  1.79780249e+00, -5.05121521e-01,
#         -9.15602070e-01,  0.00000000e+00],
#        [-1.44977239e-01,  2.37170938e+00,  2.39354861e+00,
#         -1.67335485e+00,  1.00000000e+00],
#        [ 1.96266914e-01, -1.69984969e+00, -1.85147621e+00,
#          1.22000963e+00,  0.00000000e+00],
#        [-1.95839385e+00, -1.33881668e+00, -4.89214243e-01,
#          8.13484498e-01,  0.00000000e+00],
#        [-1.04729459e+00, -7.88195034e-01,  3.36576684e+00,
#         -7.68860330e-02,  1.00000000e+00],
#        [ 7.75877939e-01, -1.45851915e+00,  1.84644670e+00,
#          5.24268258e-01,  1.00000000e+00],
#        [ 7.83647324e-01,  1.49609467e-01, -3.46777330e-02,
#         -7.73137420e-02,  1.00000000e+00],
#        [ 9.31606746e-01,  1.09259383e+00,  2.01560862e+00,
#         -9.09753929e-01,  1.00000000e+00],
#        [ 1.01357779e+00, -1.28178268e+00, -1.66107454e+00,
#          9.60260826e-01,  0.00000000e+00],
#          6.49356292e-01,  1.00000000e+00],
#        [ 8.83974953e-01, -5.38220450e-01,  1.78972621e+00,
#          2.48644090e-02,  0.00000000e+00],
#        [ 1.19124780e+00, -2.06188190e-01,  9.87910355e-01,
#         -3.64567560e-02,  1.00000000e+00],
#        [-1.09353476e+00, -2.28277400e+00, -4.47978949e-01,
#          1.32830417e+00,  0.00000000e+00],
#        [-6.57946038e-01,  1.08313755e+00,  1.28259573e+00,
#         -7.93029497e-01,  1.00000000e+00],
#        [-6.54580430e-02, -1.06496404e+00,  1.41278214e+00,
#          3.72982305e-01,  1.00000000e+00],
#        [-6.09847086e-01,  1.05993262e+00,  1.38339715e+00,
#         -7.95553379e-01,  1.00000000e+00],
#        [ 5.68733274e-01,  7.20387665e-01, -1.44120059e+00,
#         -1.78443027e-01,  0.00000000e+00],
#        [-1.38669392e+00, -6.75072040e-01, -1.39593657e+00,
#          5.85006449e-01,  0.00000000e+00],
#        [-5.93663060e-01, -1.83252933e+00, -2.08737362e+00,
#          1.32913689e+00,  0.00000000e+00],
#        [ 1.42696016e+00,  9.58861285e-01, -2.28600263e+00,
#         -1.81578100e-01,  0.00000000e+00],
#        [-1.11957965e+00,  9.24154436e-01, -1.30242196e+00,
#         -3.12038994e-01,  0.00000000e+00],
#        [ 7.53824250e-01, -6.41490456e-01, -4.43140114e-01,
#          4.21531150e-01,  0.00000000e+00],
#        [ 1.43501662e+00,  1.33941273e+00, -7.81380893e-01,
#         -6.20533434e-01,  0.00000000e+00],
#        [ 1.84081270e+00,  3.79306332e-01,  1.78116824e+00,
#         -4.80335634e-01,  1.00000000e+00],
#        [ 2.04550266e+00,  7.47357298e-01,  3.64220971e-01,
#         -4.67967766e-01,  1.00000000e+00]])

# %%
n_inp = len(dataset[0]) - 1
n_out = len(set([row[-1] for row in dataset]))
print(n_inp,n_out)
# Out:
# 4 2

# %%
#splitting into test and train datset
#the data is split in the ratio 3:1
train_dataset=dataset[:150]
test_dataset=dataset[150:]

# %%
#feeding the datset into the network
net=create_W(n_inp,1,n_out)
train_MLP(net, train_dataset, 0.5, 100, n_out)
# Out:
# =>epoch=0, =>lrate=0.500, =>error=77.718
# =>epoch=1, =>lrate=0.500, =>error=53.646
# =>epoch=2, =>lrate=0.500, =>error=33.279
# =>epoch=3, =>lrate=0.500, =>error=26.737
# =>epoch=4, =>lrate=0.500, =>error=24.241
# =>epoch=5, =>lrate=0.500, =>error=23.044
# =>epoch=6, =>lrate=0.500, =>error=22.368
# =>epoch=7, =>lrate=0.500, =>error=21.920
# =>epoch=8, =>lrate=0.500, =>error=21.575
# =>epoch=9, =>lrate=0.500, =>error=21.316
# =>epoch=10, =>lrate=0.500, =>error=21.140
# =>epoch=11, =>lrate=0.500, =>error=21.022
# =>epoch=12, =>lrate=0.500, =>error=20.927
# =>epoch=13, =>lrate=0.500, =>error=20.815
# =>epoch=14, =>lrate=0.500, =>error=20.670
# =>epoch=15, =>lrate=0.500, =>error=20.500
# =>epoch=16, =>lrate=0.500, =>error=20.320
# =>epoch=17, =>lrate=0.500, =>error=20.144
# =>epoch=18, =>lrate=0.500, =>error=19.982
# =>epoch=19, =>lrate=0.500, =>error=19.840
# =>epoch=20, =>lrate=0.500, =>error=19.720
# =>epoch=21, =>lrate=0.500, =>error=19.618
# =>epoch=22, =>lrate=0.500, =>error=19.534
# =>epoch=23, =>lrate=0.500, =>error=19.464
# =>epoch=24, =>lrate=0.500, =>error=19.405
# =>epoch=25, =>lrate=0.500, =>error=19.356
# =>epoch=26, =>lrate=0.500, =>error=19.314
# =>epoch=27, =>lrate=0.500, =>error=19.278
# =>epoch=28, =>lrate=0.500, =>error=19.247
# =>epoch=29, =>lrate=0.500, =>error=19.220
# =>epoch=30, =>lrate=0.500, =>error=19.197
# =>epoch=31, =>lrate=0.500, =>error=19.177
# =>epoch=32, =>lrate=0.500, =>error=19.159
# =>epoch=33, =>lrate=0.500, =>error=19.144
# =>epoch=34, =>lrate=0.500, =>error=19.130
# =>epoch=35, =>lrate=0.500, =>error=19.118
# =>epoch=36, =>lrate=0.500, =>error=19.108
# =>epoch=37, =>lrate=0.500, =>error=19.099
# =>epoch=38, =>lrate=0.500, =>error=19.091
# =>epoch=39, =>lrate=0.500, =>error=19.084
# =>epoch=40, =>lrate=0.500, =>error=19.078
# =>epoch=41, =>lrate=0.500, =>error=19.073
# =>epoch=42, =>lrate=0.500, =>error=19.068
# =>epoch=43, =>lrate=0.500, =>error=19.065
# =>epoch=44, =>lrate=0.500, =>error=19.061
# =>epoch=45, =>lrate=0.500, =>error=19.059
# =>epoch=46, =>lrate=0.500, =>error=19.056
# =>epoch=47, =>lrate=0.500, =>error=19.055
# =>epoch=48, =>lrate=0.500, =>error=19.053
# =>epoch=49, =>lrate=0.500, =>error=19.052
# =>epoch=50, =>lrate=0.500, =>error=19.051
# =>epoch=51, =>lrate=0.500, =>error=19.050
# =>epoch=52, =>lrate=0.500, =>error=19.050
# =>epoch=53, =>lrate=0.500, =>error=19.049
# =>epoch=54, =>lrate=0.500, =>error=19.049
# =>epoch=55, =>lrate=0.500, =>error=19.049
# =>epoch=56, =>lrate=0.500, =>error=19.049
# =>epoch=57, =>lrate=0.500, =>error=19.049
# =>epoch=58, =>lrate=0.500, =>error=19.049
# =>epoch=59, =>lrate=0.500, =>error=19.050
# =>epoch=60, =>lrate=0.500, =>error=19.050
# =>epoch=61, =>lrate=0.500, =>error=19.050
# =>epoch=62, =>lrate=0.500, =>error=19.050
# =>epoch=63, =>lrate=0.500, =>error=19.051
# =>epoch=64, =>lrate=0.500, =>error=19.051
# =>epoch=65, =>lrate=0.500, =>error=19.051
# =>epoch=66, =>lrate=0.500, =>error=19.051
# =>epoch=67, =>lrate=0.500, =>error=19.051
# =>epoch=68, =>lrate=0.500, =>error=19.051
# =>epoch=69, =>lrate=0.500, =>error=19.051
# =>epoch=70, =>lrate=0.500, =>error=19.051
# =>epoch=71, =>lrate=0.500, =>error=19.050
# =>epoch=72, =>lrate=0.500, =>error=19.050
# =>epoch=73, =>lrate=0.500, =>error=19.050
# =>epoch=74, =>lrate=0.500, =>error=19.049
# =>epoch=75, =>lrate=0.500, =>error=19.049
# =>epoch=76, =>lrate=0.500, =>error=19.048
# =>epoch=77, =>lrate=0.500, =>error=19.047
# =>epoch=78, =>lrate=0.500, =>error=19.046
# =>epoch=79, =>lrate=0.500, =>error=19.045
# =>epoch=80, =>lrate=0.500, =>error=19.044
# =>epoch=81, =>lrate=0.500, =>error=19.043
# =>epoch=82, =>lrate=0.500, =>error=19.042
# =>epoch=83, =>lrate=0.500, =>error=19.040
# =>epoch=84, =>lrate=0.500, =>error=19.039
# =>epoch=85, =>lrate=0.500, =>error=19.037
# =>epoch=86, =>lrate=0.500, =>error=19.036
# =>epoch=87, =>lrate=0.500, =>error=19.034
# =>epoch=88, =>lrate=0.500, =>error=19.032
# =>epoch=89, =>lrate=0.500, =>error=19.030
# =>epoch=90, =>lrate=0.500, =>error=19.028
# =>epoch=91, =>lrate=0.500, =>error=19.026
# =>epoch=92, =>lrate=0.500, =>error=19.024
# =>epoch=93, =>lrate=0.500, =>error=19.022
# =>epoch=94, =>lrate=0.500, =>error=19.020
# =>epoch=95, =>lrate=0.500, =>error=19.017
# =>epoch=96, =>lrate=0.500, =>error=19.015
# =>epoch=97, =>lrate=0.500, =>error=19.013
# =>epoch=98, =>lrate=0.500, =>error=19.010
# =>epoch=99, =>lrate=0.500, =>error=19.007

# %%
#learned weights of the network
for layer in net:
    print(layer)
# Out:
# [{'W': [0.26023774893564044, -1.416259372199305, 10.830561108799797, -0.17579757526175338, -2.406868292931135], 'output': 0.9999995694939275, 'delta': 5.981062014024875e-09}]
# [{'W': [-5.992630992984874, 2.6644014905663544], 'output': 0.034654194050033775, 'delta': -0.0011592964873913263}, {'W': [5.992634961165923, -2.6644030957380123], 'output': 0.9653458851743792, 'delta': 0.0011592912819055072}]

# %%
#applying on training dataset ie. 150 rows

y_train=[]
pred=[]
for row in train_dataset:
    prediction = prediction_def(net, row)
    y_train.append(int(row[-1]))
    pred.append(prediction)

# %%
#Final Results on training-->

print("Accuracy Result: ",accuracy_score(y_train,pred))
print("Confusion Matrix: ",confusion_matrix(y_train,pred))
print("Precision Result: ",precision_score(y_train, pred))
print("recall Result: ",recall_score(y_train, pred))
# Out:
# Accuracy Result:  0.9266666666666666
# Confusion Matrix:  [[68  5]
#  [ 6 71]]
# Precision Result:  0.9342105263157895
# recall Result:  0.922077922077922

# %%
#applying on testing dataset ie. 50 rows
y_test=[]
pred=[]
for row in test_dataset:
    prediction = prediction_def(net, row)
    y_test.append(row[-1])
    pred.append(prediction)

# %%
#Final Results on testing-->


print("Accuracy Result: ",accuracy_score(y_test,pred))
print("Confusion Matrix: ",confusion_matrix(y_test,pred))
print("Precision Result: ",precision_score(y_test, pred))
print("recall Result: ",recall_score(y_test, pred))
# Out:
# Accuracy Result:  0.94
# Confusion Matrix:  [[25  2]
#  [ 1 22]]
# Precision Result:  0.9166666666666666
# recall Result:  0.9565217391304348
